# %% [markdown]
# # Exploratory Data Analysis
# Based on https://towardsdatascience.com/exploratory-data-analysis-8fc1cb20fd15 and https://nbviewer.org/github/PBPatil/Exploratory_Data_Analysis-Wine_Quality_Dataset/blob/master/winequality_white.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("hipparcos-voidmain.csv")
df.head()
# Out:
#   Catalog  HIP Proxy        RAhms        DEdms  Vmag  VarFlag r_Vmag  \
# 0       H    1   NaN  00 00 00.22  +01 05 20.4  9.10      NaN      H
# 1       H    2   NaN  00 00 00.91  -19 29 55.8  9.27      NaN      G
# 2       H    3   NaN  00 00 01.20  +38 51 33.4  6.61      NaN      G
# 3       H    4   NaN  00 00 02.01  -51 53 36.8  8.06      NaN      H
# 4       H    5   NaN  00 00 02.39  -40 35 28.4  8.55      NaN      H
#
#       RAdeg      DEdeg  ... Survey  Chart  Notes        HD         BD  \
# 0  0.000912   1.089013  ...      S    NaN    NaN  224700.0  B+00 5077
# 1  0.003797 -19.498837  ...    NaN    NaN    NaN  224690.0  B-20 6688
# 2  0.005008  38.859286  ...      S    NaN    NaN  224699.0  B+38 5108
# 3  0.008382 -51.893546  ...      S    NaN    NaN  224707.0        NaN
# 4  0.009965 -40.591224  ...    NaN    NaN    NaN  224705.0        NaN
#
#           CoD         CPD  (V-I)red  SpType  r_SpType
# 0         NaN         NaN      0.66      F5         S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118218 entries, 0 to 118217
# Data columns (total 78 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Catalog    118218 non-null  object
#  1   HIP        118218 non-null  int64
#  2   Proxy      10925 non-null   object
#  3   RAhms      118218 non-null  object
#  4   DEdms      118218 non-null  object
#  5   Vmag       118217 non-null  float64
#  6   VarFlag    11562 non-null   float64
#  7   r_Vmag     118217 non-null  object
#  8   RAdeg      117955 non-null  float64
#  9   DEdeg      117955 non-null  float64
#  10  AstroRef   13734 non-null   object
#  11  Plx        117955 non-null  float64
#  12  pmRA       117955 non-null  float64
#  13  pmDE       117955 non-null  float64
#  14  e_RAdeg    117955 non-null  float64
#  15  e_DEdeg    117955 non-null  float64
#  16  e_Plx      117955 non-null  float64
#  17  e_pmRA     117955 non-null  float64
# ...

# %%
df.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
df.quality.value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
#cmap = sns.diverging_palette(230, 20, as_cmap=True)
cmap = sns.diverging_palette(10, 250, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(figsize=(20, 9))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
# Boxplot or whiskers plot
keys = len(df.keys())
f, axs = plt.subplots(1,keys, figsize=(20, 9))
for i, key in enumerate(df.keys()):
    sns.boxplot(y=df[key], ax=axs[i])

# %%
# KDE kernel plot
f, axs = plt.subplots(keys, 1, figsize=(10, 20))
for i, key in enumerate(df.keys()):
    sns.kdeplot(data=df[key], ax=axs[i], fill=True)
    axs[i].set_ylabel(key)
    axs[i].set_xlabel("")

# %% [markdown]
# # Some EDA using pandas plots
# Partly based on https://towardsdatascience.com/exploratory-data-analysis-eda-visualization-using-pandas-ca5a04271607

# %%
# Scatter plot
pd.plotting.scatter_matrix(df, diagonal="kde", figsize=(14,10))
# Out:
# array([[<AxesSubplot:xlabel='fixed acidity', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='volatile acidity', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='citric acid', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='residual sugar', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='chlorides', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='free sulfur dioxide', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='total sulfur dioxide', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='density', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='pH', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='sulphates', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='alcohol', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>],
#        [<AxesSubplot:xlabel='fixed acidity', ylabel='volatile acidity'>,
#         <AxesSubplot:xlabel='volatile acidity', ylabel='volatile acidity'>,
# ...

# %%
# Other way to create boxplot using only pandas
f, ax = plt.subplots(figsize=(20, 10))
df.plot.box(vert = False, grid = True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(figsize=(20, 10))
df.plot.hist(bins=100, alpha=0.3, ax=ax, title="Histogran")
# Out:
# <AxesSubplot:title={'center':'Histogran'}, ylabel='Frequency'>

# %%
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/mz/4m2hrcfn12l3j_lp6qbpkc6h0005hl/T/ipykernel_2733/1928666696.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_eca03_row0_col0, #T_eca03_row1_col1, #T_eca03_row2_col2, #T_eca03_row3_col3, #T_eca03_row4_col4, #T_eca03_row5_col5, #T_eca03_row6_col6, #T_eca03_row7_col7, #T_eca03_row8_col8, #T_eca03_row9_col9, #T_eca03_row10_col10, #T_eca03_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_eca03_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_eca03_row0_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_eca03_row0_col3, #T_eca03_row0_col6, #T_eca03_row1_col6, #T_eca03_row4_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_eca03_row0_col4, #T_eca03_row1_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# ...

# %%
df.plot.scatter(x="sulphates", y="quality")
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
# Number of null values
df.isnull( ).sum( )
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.memory_usage( )
# Out:
# Index                     128
# fixed acidity           39184
# volatile acidity        39184
# citric acid             39184
# residual sugar          39184
# chlorides               39184
# free sulfur dioxide     39184
# total sulfur dioxide    39184
# density                 39184
# pH                      39184
# sulphates               39184
# alcohol                 39184
# quality                 39184
# dtype: int64

# %%
df.nlargest(10, "quality")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 774             9.1              0.27         0.45            10.6      0.035
# 820             6.6              0.36         0.29             1.6      0.021
# 827             7.4              0.24         0.36             2.0      0.031
# 876             6.9              0.36         0.34             4.2      0.018
# 1605            7.1              0.26         0.49             2.2      0.032
# 17              6.2              0.66         0.48             1.2      0.029
# 20              6.2              0.66         0.48             1.2      0.029
# 22              6.8              0.26         0.42             1.7      0.049
# 68              6.7              0.23         0.31             2.1      0.046
# 74              6.7              0.23         0.31             2.1      0.046
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# # Other seaborn plots
#
# Based on https://seaborn.pydata.org/tutorial/function_overview.html
#
# Plot grids https://seaborn.pydata.org/tutorial/axis_grids.html
#
# See palettes here https://seaborn.pydata.org/tutorial/color_palettes.html
#
# More https://www.webagesolutions.com/blog/data-visualization-and-eda-with-pandas-and-seaborn

# %%
f, ax = plt.subplots(figsize=(8, 4))
sns.scatterplot(data=df, x="alcohol", y="pH", hue="quality", ax=ax, palette="Set2")
#sns.scatterplot(data=df, x="density", y="residual sugar", hue="quality", ax=ax)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='pH'>

# %%
sns.jointplot(data=df, x="alcohol", y="pH", hue="quality", palette="Set2")

# %%
sns.pairplot(data=df, hue="quality", palette="Set2")

# %%
sns.scatterplot(data=df, x="alcohol", y="pH", hue="sulphates", palette="Spectral")
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='pH'>

# %%
sns.set()
sns.set_style('whitegrid') 
sns.jointplot(data=df, x="alcohol", y="pH", palette="Spectral", kind="kde", fill=True)

# %%
sns.displot(data=df, x="alcohol", y="sulphates", kind="kde")

# %%
dfnew = df[["alcohol", "sulphates", "pH", "chlorides"]]
g = sns.PairGrid(dfnew)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
